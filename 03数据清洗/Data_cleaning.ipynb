# %% [markdown]
# ## 一、数据导入

# %%
#读取数据
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns #要注意的是一旦导入了seaborn，matplotlib的默认作图风格就会被覆盖成seaborn的格式
import pandas
users=pandas.read_csv("./train_users_2.csv/train_users_2.csv")

# %% [markdown]
# #### 查看数据信息

# %%
users.info() # 查看数据整体信息
users.head() # 查看前5个数据信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 15.5+ MB
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %% [markdown]
# ## 二、格式转换

# %% [markdown]
# #### 转换时间

# %%
users["date_account_created"] = pandas.to_datetime(users["date_account_created"],format="%Y-%m-%d")
users["timestamp_first_active"] = pandas.to_datetime(users["timestamp_first_active"],format="%Y%m%d%H%M%S")
users["date_first_booking"] = pandas.to_datetime(users["date_first_booking"],format="%Y-%m-%d")
users.info()
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 17.1+ MB
#            id date_account_created timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 1  820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# 3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 4  87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %% [markdown]
# #### 转换数字

# %%
users["age"] = users["age"].astype(dtype='str',errors="ignore")
users.info()
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        213451 non-null object
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), int64(1), object(12)
# memory usage: 16.3+ MB
#            id date_account_created timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 1  820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# 3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 4  87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   nan      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
users["age"] = users["age"].astype(dtype='float',errors="ignore")
users.info()
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 17.1+ MB
#            id date_account_created timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 1  820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# 3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 4  87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %% [markdown]
# ##  三、缺失处理

# %% [markdown]
# #### 1.直接丢弃

# %%
users["age"].dropna()
# Out:
# 1         38.0
# 2         56.0
# 3         42.0
# 4         41.0
# 6         46.0
# 7         47.0
# 8         50.0
# 9         46.0
# 10        36.0
# 11        47.0
# 13        37.0
# 14        36.0
# 15        33.0
# 17        31.0
# 19        29.0
# 21        30.0
# 22        40.0
# 24        40.0
# 25        26.0
# 27        32.0
# 28        35.0
# 29        37.0
# 30        42.0
# 31        31.0
# 32        31.0
# 33        29.0
# 34        59.0
# 35        49.0
# 36        31.0
# 37        30.0
#           ...
# 213390    30.0
# 213391    29.0
# 213393    26.0
# 213395    33.0
# 213398    39.0
# 213400    53.0
# 213401    45.0
# 213402    32.0
# 213403    27.0
# 213405    23.0
# 213406    35.0
# 213407    21.0
# 213408    69.0
# 213409    28.0
# 213410    33.0
# 213412    50.0
# 213415    55.0
# 213417    46.0
# 213423    20.0
# 213424    32.0
# 213425    30.0
# 213430    19.0
# 213432    31.0
# 213439    43.0
# 213440    24.0
# 213441    34.0
# 213443    36.0
# 213445    23.0
# 213446    32.0
# 213448    32.0
# Name: age, Length: 125461, dtype: float64

# %% [markdown]
# #### 2.填充数值（均值、中位数、众数或者经验数值）

# %%
users["age"].describe()
# Out:
# count    125461.000000
# mean         49.668335
# std         155.666612
# min           1.000000
# 25%          28.000000
# 50%          34.000000
# 75%          43.000000
# max        2014.000000
# Name: age, dtype: float64

# %%
users.fillna(users["age"].mean())  # 填充平均值
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# 5       osr2jwljor           2010-01-01    2010-01-01 21:56:19
# 6       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 7       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# 8       a1vcnhxeij           2010-01-04    2010-01-04 00:42:11
# 9       6uh8zyj2gn           2010-01-04    2010-01-04 02:37:58
# 10      yuuqmid2rp           2010-01-04    2010-01-04 19:42:51
# 11      om1ss59ys8           2010-01-05    2010-01-05 05:18:12
# 12      k6np330cm1           2010-01-05    2010-01-05 06:08:59
# 13      dy3rgx56cu           2010-01-05    2010-01-05 08:32:59
# 14      ju3h98ch3w           2010-01-07    2010-01-07 05:58:20
# 15      v4d5rl22px           2010-01-07    2010-01-07 20:45:55
# 16      2dwbwkx056           2010-01-07    2010-01-07 21:51:25
# 17      frhre329au           2010-01-07    2010-01-07 22:46:25
# 18      cxlg85pg1r           2010-01-08    2010-01-08 01:56:41
# 19      gdka1q5ktd           2010-01-10    2010-01-10 01:08:17
# 20      qdubonn3uk           2010-01-10    2010-01-10 15:21:20
# 21      qsibmuz9sx           2010-01-10    2010-01-10 22:09:41
# 22      80f7dwscrn           2010-01-11    2010-01-11 03:14:38
# 23      jha93x042q           2010-01-11    2010-01-11 22:40:15
# 24      7i49vnuav6           2010-01-11    2010-01-11 23:08:08
# 25      al8bcetz0g           2010-01-12    2010-01-12 13:14:44
# 26      bjg0m5otl3           2010-01-12    2010-01-12 15:54:20
# 27      hfrl5gle36           2010-01-12    2010-01-12 20:59:49
# 28      tp6x3md0n4           2010-01-13    2010-01-13 04:46:50
# 29      hql77nu2lk           2010-01-13    2010-01-13 06:43:33
# ...            ...                  ...                    ...
# 213421  c98s3h7kgj           2014-06-30    2014-06-30 23:11:37
# 213422  ytmpiwb8hj           2014-06-30    2014-06-30 23:12:46
# 213423  3dx1jk6yk2           2014-06-30    2014-06-30 23:15:48
# 213424  hcfj07iowv           2014-06-30    2014-06-30 23:18:59
# 213425  l1f71f9vsj           2014-06-30    2014-06-30 23:21:19
# 213426  15bj4ahmhf           2014-06-30    2014-06-30 23:23:31
# 213427  qwpybxfjdl           2014-06-30    2014-06-30 23:25:39
# 213428  k4t61wuvyq           2014-06-30    2014-06-30 23:26:34
# 213429  mhh7b52z44           2014-06-30    2014-06-30 23:27:12
# 213430  79wk7k2k5t           2014-06-30    2014-06-30 23:31:32
# 213431  ftwmocvwlq           2014-06-30    2014-06-30 23:32:03
# 213432  rg7ayg1tob           2014-06-30    2014-06-30 23:32:24
# 213433  2f24umzkuv           2014-06-30    2014-06-30 23:34:27
# 213434  or77n2ojuj           2014-06-30    2014-06-30 23:36:40
# 213435  0a5bnb9bs4           2014-06-30    2014-06-30 23:38:51
# 213436  6fzrn49sfn           2014-06-30    2014-06-30 23:41:13
# 213437  r0jq0devgy           2014-06-30    2014-06-30 23:42:43
# 213438  v5lq9bj8gv           2014-06-30    2014-06-30 23:44:29
# 213439  msucfwmlzc           2014-06-30    2014-06-30 23:47:29
# 213440  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 213441  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 213442  rf0ay567js           2014-06-30    2014-06-30 23:53:09
# 213443  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 213444  40o1ivh6cb           2014-06-30    2014-06-30 23:53:52
# 213445  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#                   date_first_booking     gender        age signup_method  \
# 0      1970-01-01 00:00:00.000000049  -unknown-  49.668335      facebook
# 1      1970-01-01 00:00:00.000000049       MALE  38.000000      facebook
# 2      2010-08-02 00:00:00.000000000     FEMALE  56.000000         basic
# 3      2012-09-08 00:00:00.000000000     FEMALE  42.000000      facebook
# 4      2010-02-18 00:00:00.000000000  -unknown-  41.000000         basic
# 5      2010-01-02 00:00:00.000000000  -unknown-  49.668335         basic
# 6      2010-01-05 00:00:00.000000000     FEMALE  46.000000         basic
# 7      2010-01-13 00:00:00.000000000     FEMALE  47.000000         basic
# 8      2010-07-29 00:00:00.000000000     FEMALE  50.000000         basic
# 9      2010-01-04 00:00:00.000000000  -unknown-  46.000000         basic
# 10     2010-01-06 00:00:00.000000000     FEMALE  36.000000         basic
# 11     1970-01-01 00:00:00.000000049     FEMALE  47.000000         basic
# 12     2010-01-18 00:00:00.000000000  -unknown-  49.668335         basic
# 13     1970-01-01 00:00:00.000000049     FEMALE  37.000000         basic
# 14     1970-01-01 00:00:00.000000049     FEMALE  36.000000         basic
# 15     2010-01-08 00:00:00.000000000     FEMALE  33.000000         basic
# 16     1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 17     2010-01-09 00:00:00.000000000  -unknown-  31.000000         basic
# 18     1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 19     2010-01-10 00:00:00.000000000     FEMALE  29.000000         basic
# 20     2010-01-18 00:00:00.000000000  -unknown-  49.668335         basic
# 21     2010-01-11 00:00:00.000000000       MALE  30.000000         basic
# 22     2010-01-11 00:00:00.000000000  -unknown-  40.000000         basic
# 23     1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 24     1970-01-01 00:00:00.000000049     FEMALE  40.000000         basic
# 25     2010-01-15 00:00:00.000000000     FEMALE  26.000000         basic
# 26     1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 27     2010-01-22 00:00:00.000000000     FEMALE  32.000000         basic
# 28     2010-01-13 00:00:00.000000000  -unknown-  35.000000         basic
# 29     2010-01-19 00:00:00.000000000  -unknown-  37.000000         basic
# ...                              ...        ...        ...           ...
# 213421 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213422 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213423 1970-01-01 00:00:00.000000049     FEMALE  20.000000      facebook
# 213424 1970-01-01 00:00:00.000000049     FEMALE  32.000000      facebook
# 213425 1970-01-01 00:00:00.000000049     FEMALE  30.000000      facebook
# 213426 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213427 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213428 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213429 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213430 1970-01-01 00:00:00.000000049  -unknown-  19.000000         basic
# 213431 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213432 1970-01-01 00:00:00.000000049       MALE  31.000000      facebook
# 213433 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213434 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213435 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213436 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213437 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213438 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213439 2015-03-16 00:00:00.000000000       MALE  43.000000         basic
# 213440 1970-01-01 00:00:00.000000049     FEMALE  24.000000         basic
# 213441 2014-08-13 00:00:00.000000000     FEMALE  34.000000         basic
# 213442 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213443 2014-07-13 00:00:00.000000000     FEMALE  36.000000         basic
# 213444 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213445 2014-07-02 00:00:00.000000000     FEMALE  23.000000         basic
# 213446 1970-01-01 00:00:00.000000049       MALE  32.000000         basic
# 213447 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213448 1970-01-01 00:00:00.000000049  -unknown-  32.000000         basic
# 213449 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
# 213450 1970-01-01 00:00:00.000000049  -unknown-  49.668335         basic
#
#         signup_flow language affiliate_channel affiliate_provider  \
# 0                 0       en            direct             direct
# 1                 0       en               seo             google
# 2                 3       en            direct             direct
# 3                 0       en            direct             direct
# 4                 0       en            direct             direct
# 5                 0       en             other              other
# 6                 0       en             other         craigslist
# 7                 0       en            direct             direct
# 8                 0       en             other         craigslist
# 9                 0       en             other         craigslist
# 10                0       en             other         craigslist
# 11                0       en             other         craigslist
# 12                0       en            direct             direct
# 13                0       en             other         craigslist
# 14                0       en             other         craigslist
# 15                0       en            direct             direct
# 16                0       en             other         craigslist
# 17                0       en             other         craigslist
# 18                0       en               seo           facebook
# 19                0       en            direct             direct
# 20                0       en            direct             direct
# 21                0       en            direct             direct
# 22                0       en               seo             google
# 23                0       en             other         craigslist
# 24                0       en               seo             google
# 25                0       en             other         craigslist
# 26                0       en             other              other
# 27                0       en             other         craigslist
# 28                0       en            direct             direct
# 29                0       en            direct             direct
# ...             ...      ...               ...                ...
# 213421            0       en            direct             direct
# 213422            0       en            direct             direct
# 213423           25       en            direct             direct
# 213424            0       en            direct             direct
# 213425            0       en            direct             direct
# 213426            0       en            direct             direct
# 213427            0       en            direct             direct
# 213428           23       en            direct             direct
# 213429           25       en            direct             direct
# 213430            0       en            direct             direct
# 213431            0       en            direct             direct
# 213432            0       en            direct             direct
# 213433            0       en         sem-brand             google
# 213434            0       en               seo           facebook
# 213435            0       en               seo             google
# 213436           25       en            direct             direct
# 213437           23       en            direct             direct
# 213438           25       en            direct             direct
# 213439            0       en            direct             direct
# 213440           25       en            direct             direct
# 213441            0       en            direct             direct
# 213442            0       en         sem-brand             google
# 213443            0       en         sem-brand             google
# 213444            0       en            direct             direct
# 213445            0       en         sem-brand             google
# 213446            0       en         sem-brand             google
# 213447            0       en            direct             direct
# 213448            0       en            direct             direct
# 213449           25       en             other              other
# 213450           25       en            direct             direct
#
#        first_affiliate_tracked signup_app first_device_type  first_browser  \
# 0                    untracked        Web       Mac Desktop         Chrome
# 1                    untracked        Web       Mac Desktop         Chrome
# 2                    untracked        Web   Windows Desktop             IE
# 3                    untracked        Web       Mac Desktop        Firefox
# 4                    untracked        Web       Mac Desktop         Chrome
# 5                          omg        Web       Mac Desktop         Chrome
# 6                    untracked        Web       Mac Desktop         Safari
# 7                          omg        Web       Mac Desktop         Safari
# 8                    untracked        Web       Mac Desktop         Safari
# 9                          omg        Web       Mac Desktop        Firefox
# 10                   untracked        Web       Mac Desktop        Firefox
# 11                   untracked        Web            iPhone      -unknown-
# 12                     49.6683        Web     Other/Unknown      -unknown-
# 13                      linked        Web       Mac Desktop        Firefox
# 14                   untracked        Web            iPhone  Mobile Safari
# 15                   untracked        Web   Windows Desktop         Chrome
# 16                     49.6683        Web     Other/Unknown      -unknown-
# 17                     49.6683        Web     Other/Unknown      -unknown-
# 18                     49.6683        Web     Other/Unknown      -unknown-
# 19                   untracked        Web       Mac Desktop         Chrome
# 20                     49.6683        Web     Other/Unknown      -unknown-
# 21                      linked        Web       Mac Desktop         Chrome
# 22                   untracked        Web            iPhone      -unknown-
# 23                   untracked        Web       Mac Desktop         Safari
# 24                   untracked        Web       Mac Desktop        Firefox
# 25                   untracked        Web       Mac Desktop         Chrome
# 26                   untracked        Web     Other/Unknown      -unknown-
# 27                   untracked        Web   Desktop (Other)         Chrome
# 28                     49.6683        Web     Other/Unknown      -unknown-
# 29                   untracked        Web    Android Tablet      -unknown-
# ...                        ...        ...               ...            ...
# 213421                  linked        Web       Mac Desktop        Firefox
# 213422               untracked        Web   Windows Desktop             IE
# 213423               untracked        iOS            iPhone      -unknown-
# 213424                  linked        Web   Windows Desktop         Chrome
# 213425                  linked        Web   Windows Desktop         Chrome
# 213426               untracked      Moweb     Android Phone  Chrome Mobile
# 213427                  linked        Web   Desktop (Other)         Chrome
# 213428               untracked    Android     Android Phone      -unknown-
# 213429               untracked        iOS            iPhone      -unknown-
# 213430                  linked        Web       Mac Desktop         Chrome
# 213431               untracked        Web   Windows Desktop        Firefox
# 213432           tracked-other        Web       Mac Desktop         Safari
# 213433               untracked        Web              iPad  Mobile Safari
# 213434                 product        Web       Mac Desktop         Chrome
# 213435               untracked        Web   Windows Desktop         Chrome
# 213436               untracked        iOS            iPhone      -unknown-
# 213437               untracked    Android    Android Tablet      -unknown-
# 213438               untracked        iOS            iPhone      -unknown-
# 213439               untracked        Web   Windows Desktop        Firefox
# 213440               untracked        iOS            iPhone  Mobile Safari
# 213441                  linked        Web       Mac Desktop         Chrome
# 213442                     omg        Web       Mac Desktop         Chrome
# 213443                  linked        Web       Mac Desktop         Safari
# 213444                  linked        Web   Windows Desktop         Chrome
# 213445                     omg        Web   Windows Desktop             IE
# 213446                     omg        Web       Mac Desktop         Safari
# 213447                  linked        Web   Windows Desktop         Chrome
# 213448               untracked        Web       Mac Desktop        Firefox
# 213449           tracked-other        iOS            iPhone  Mobile Safari
# 213450               untracked        iOS            iPhone      -unknown-
#
#        country_destination
# 0                      NDF
# 1                      NDF
# 2                       US
# 3                    other
# 4                       US
# 5                       US
# 6                       US
# 7                       US
# 8                       US
# 9                       US
# 10                      US
# 11                     NDF
# 12                      FR
# 13                     NDF
# 14                     NDF
# 15                      CA
# 16                     NDF
# 17                      US
# 18                     NDF
# 19                      FR
# 20                      US
# 21                      US
# 22                      US
# 23                     NDF
# 24                     NDF
# 25                      FR
# 26                     NDF
# 27                      US
# 28                      FR
# 29                      US
# ...                    ...
# 213421                 NDF
# 213422                 NDF
# 213423                 NDF
# 213424                 NDF
# 213425                 NDF
# 213426                 NDF
# 213427                 NDF
# 213428                 NDF
# 213429                 NDF
# 213430                 NDF
# 213431                 NDF
# 213432                 NDF
# 213433                 NDF
# 213434                 NDF
# 213435                 NDF
# 213436                 NDF
# 213437                 NDF
# 213438                 NDF
# 213439                  US
# 213440                 NDF
# 213441                  ES
# 213442                 NDF
# 213443                  US
# 213444                 NDF
# 213445                  US
# 213446                 NDF
# 213447                 NDF
# 213448                 NDF
# 213449                 NDF
# 213450                 NDF
#
# [213451 rows x 16 columns]

# %% [markdown]
# ## 四、重复数据处理

# %%
users.info()
users["id"] = users["id"].drop_duplicates()  # 去除重复数据
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 17.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 17.1+ MB

# %% [markdown]
# ## 五、异常数据处理

# %%
import seaborn
seaborn.distplot(users["age"].dropna())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
seaborn.boxplot(users["age"].dropna())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 正常人的年龄很明显不会大于120

# %%
users.info()
users=users[users["age"]<120]
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null datetime64[ns]
# date_first_booking         88908 non-null datetime64[ns]
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 17.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124680 entries, 1 to 213448
# Data columns (total 16 columns):
# id                         124680 non-null object
# date_account_created       124680 non-null datetime64[ns]
# timestamp_first_active     124680 non-null datetime64[ns]
# date_first_booking         68156 non-null datetime64[ns]
# gender                     124680 non-null object
# age                        124680 non-null float64
# signup_method              124680 non-null object
# signup_flow                124680 non-null int64
# language                   124680 non-null object
# affiliate_channel          124680 non-null object
# affiliate_provider         124680 non-null object
# first_affiliate_tracked    122682 non-null object
# signup_app                 124680 non-null object
# first_device_type          124680 non-null object
# first_browser              124680 non-null object
# country_destination        124680 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(11)
# memory usage: 10.9+ MB
